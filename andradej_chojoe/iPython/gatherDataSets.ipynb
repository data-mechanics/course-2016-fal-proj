# %%
import urllib.request
import json
import dml
import prov.model
import datetime
import uuid

class gatherDataSets(dml.Algorithm):
    contributor = 'andradej_chojoe'
    reads = []
    writes = ['andrade_chojoe.bigbelly', 'andrade_chojoe.trashSch', 'andrade_chojoe.codeEnf', 'andrade_chojoe.foodEst', 'andrade_chojoe.hotline']

    @staticmethod
    def execute(trial = False):
        startTime = datetime.datetime.now()
        
        #Set up database connection
        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('andradej_chojoe', 'andradej_chojoe')
        
        dataSets = {'bigbelly': 'https://data.cityofboston.gov/resource/nybq-xu5r.json', \
                   'trashSch': 'https://data.cityofboston.gov/resource/je5q-tbjf.json', \
                   'codeEnf': 'https://data.cityofboston.gov/resource/w39n-pvs8.json', \
                   'foodEst': 'https://data.cityofboston.gov/resource/427a-3cn5.json', \
                   'hotline' : 'https://data.cityofboston.gov/resource/jbcd-dknd.json'}
        
        for ds in dataSets:
            url = dataSets[ds]
            response = urllib.request.urlopen(url).read().decode("utf-8")
            r = json.loads(response)
            s = json.dumps(r, sort_keys=True, indent=2)
            repo.dropPermanent(ds)
            repo.createPermanent(ds)
            repo['andradej_chojoe.' + ds].insert_many(r)
        
        repo.logout()
        
        endTime = datetime.datetime.now()
        
        return {"start":startTime, "end":endTime}
    
    @staticmethod
    def provenance(doc = prov.model.ProvDocument(), startTime = None, endTime = None):
        #set up the database connection.
        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('andradej_chojoe', 'andradej_chojoe')
        
        doc.add_namespace('alg', 'http://datamechanics.io/algorithm/andradej_chojoe') # The scripts are in <folder>#<filename> format.
        doc.add_namespace('dat', 'http://datamechanics.io/data/andradej_chojoe') # The data sets are in <user>#<collection> format.
        doc.add_namespace('ont', 'http://datamechanics.io/ontology#') # 'Extension', 'DataResource', 'DataSet', 'Retrieval', 'Query', or 'Computation'.
        doc.add_namespace('log', 'http://datamechanics.io/log/') # The event log.
        doc.add_namespace('bdp', 'https://data.cityofboston.gov/resource/')
    
        this_script = doc.agent('alg:#gatherDataSets', {prov.model.PROV_TYPE:prov.model.PROV['SoftwareAgent'], 'ont:Extension':'py'})
        
        bigbelly_rsc = doc.entity('bdp:nybq-xu5r', {'prov:label':'Big Belly Reports 2014', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
        get_bigbelly = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime, {'prov:label':'Get Big Belly Reports 2014'})
        doc.wasAssociatedWith(get_bigbelly, this_script)
        doc.usage(
            get_bigbelly,
            bigbelly_rsc,
            startTime,
            None,
            {prov.model.PROV_TYPE:'ont:Retrieval'}
        )
        
        trashSch_rsc = doc.entity('bdp:je5q-tbjf', {'prov:label':'Trash Schedules by Address', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
        get_trashSch = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime, {'prov:label':'Get Trash Schedules by Address '})
        doc.wasAssociatedWith(get_trashSch, this_script)
        doc.usage(
            get_trashSch,
            trashSch_rsc,
            startTime,
            None,
            {prov.model.PROV_TYPE:'ont:Retrieval'}
        )
        
        codeEnf_rsc = doc.entity('bdp:w39n-pvs8', {'prov:label':'Code Enforcement - Building and Property Violations', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
        get_codeEnf = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime, {'prov:label':'Get Code Enforcement - Building and Property Violations'})
        doc.wasAssociatedWith(get_codeEnf, this_script)
        doc.usage(
            get_codeEnf,
            codeEnf_rsc,
            startTime,
            None,
            {prov.model.PROV_TYPE:'ont:Retrieval'}
        )
        
        foodEst_rsc = doc.entity('bdp:427a-3cn5', {'prov:label':'Food Establishment Inspections', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
        get_foodEst = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime, {'prov:label':'Get Food Establishment Inspections'})
        doc.wasAssociatedWith(get_foodEst, this_script)
        doc.usage(
            get_foodEst,
            foodEst_rsc,
            startTime,
            None,
            {prov.model.PROV_TYPE:'ont:Retrieval'}
        )
        
        hotline_rsc = doc.entity('bdp:jbcd-dknd', {'prov:label':'Mayors 24 Hour Hotline', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
        get_hotline = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime, {'prov:label':'Get Mayors 24 Hour Hotline'})
        doc.wasAssociatedWith(get_hotline, this_script)
        doc.usage(
            get_hotline,
            hotline_rsc,
            startTime,
            None,
            {prov.model.PROV_TYPE:'ont:Retrieval'}
        )
        
        bigbelly = doc.entity('dat:#bigbelly', {prov.model.PROV_LABEL:'Big Belly Reports 2014', prov.model.PROV_TYPE:'ont:DataSet'})
        doc.wasAttributedTo(bigbelly, this_script)
        doc.wasGeneratedBy(bigbelly, get_bigbelly, endTime)
        doc.wasDerivedFrom(bigbelly, bigbelly_rsc, get_bigbelly, get_bigbelly, get_bigbelly)
        
        trashSch = doc.entity('dat:#trashSch', {prov.model.PROV_LABEL:'Trash Schedules by Address', prov.model.PROV_TYPE:'ont:DataSet'})
        doc.wasAttributedTo(trashSch, this_script)
        doc.wasGeneratedBy(trashSch, get_trashSch, endTime)
        doc.wasDerivedFrom(trashSch, trashSch_rsc, get_trashSch, get_trashSch, get_trashSch)
        
        codeEnf = doc.entity('dat:#codeEnf', {prov.model.PROV_LABEL:'Code Enforcement - Building and Property Violations', prov.model.PROV_TYPE:'ont:DataSet'})
        doc.wasAttributedTo(codeEnf, this_script)
        doc.wasGeneratedBy(codeEnf, get_codeEnf, endTime)
        doc.wasDerivedFrom(codeEnf, codeEnf_rsc, get_codeEnf, get_codeEnf, get_codeEnf)
        
        foodEst = doc.entity('dat:#foodEst', {prov.model.PROV_LABEL:'Food Establishment Inspections', prov.model.PROV_TYPE:'ont:DataSet'})
        doc.wasAttributedTo(foodEst, this_script)
        doc.wasGeneratedBy(foodEst, get_foodEst, endTime)
        doc.wasDerivedFrom(foodEst, foodEst_rsc, get_foodEst, get_foodEst, get_foodEst)
        
        hotline = doc.entity('dat:#hotline', {prov.model.PROV_LABEL:'Mayors 24 Hour Hotline', prov.model.PROV_TYPE:'ont:DataSet'})
        doc.wasAttributedTo(hotline, this_script)
        doc.wasGeneratedBy(hotline, get_hotline, endTime)
        doc.wasDerivedFrom(hotline, hotline_rsc, get_hotline, get_hotline, get_hotline)
        
        repo.record(doc.serialize())
        repo.logout()
        
        return doc
    
gatherDataSets.execute()
doc = gatherDataSets.provenance()
print(doc.get_provn())
print(json.dumps(json.loads(doc.serialize()), indent=4))
# Out:
# document
#   prefix alg <http://datamechanics.io/algorithm/andradej_chojoe>
#   prefix dat <http://datamechanics.io/data/andradej_chojoe>
#   prefix log <http://datamechanics.io/log/>
#   prefix bdp <https://data.cityofboston.gov/resource/>
#   prefix ont <http://datamechanics.io/ontology#>
#
#   agent(alg:andradej_chojoe#gatherDataSets, [ont:Extension="py", prov:type='prov:SoftwareAgent'])
#   entity(bdp:nybq-xu5r, [ont:Extension="json", prov:label="Big Belly Reports 2014", prov:type="ont:DataResource"])
#   activity(log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e, -, -, [prov:label="Get Big Belly Reports 2014"])
#   wasAssociatedWith(log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e, alg:andradej_chojoe#gatherDataSets, -)
#   used(log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e, bdp:nybq-xu5r, -, [prov:type="ont:Retrieval"])
#   entity(bdp:je5q-tbjf, [ont:Extension="json", prov:label="Trash Schedules by Address", prov:type="ont:DataResource"])
#   activity(log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d, -, -, [prov:label="Get Trash Schedules by Address "])
#   wasAssociatedWith(log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d, alg:andradej_chojoe#gatherDataSets, -)
#   used(log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d, bdp:je5q-tbjf, -, [prov:type="ont:Retrieval"])
#   entity(bdp:w39n-pvs8, [ont:Extension="json", prov:label="Code Enforcement - Building and Property Violations", prov:type="ont:DataResource"])
#   activity(log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3, -, -, [prov:label="Get Code Enforcement - Building and Property Violations"])
#   wasAssociatedWith(log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3, alg:andradej_chojoe#gatherDataSets, -)
#   used(log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3, bdp:w39n-pvs8, -, [prov:type="ont:Retrieval"])
#   entity(bdp:427a-3cn5, [ont:Extension="json", prov:label="Food Establishment Inspections", prov:type="ont:DataResource"])
#   activity(log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599, -, -, [prov:label="Get Food Establishment Inspections"])
#   wasAssociatedWith(log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599, alg:andradej_chojoe#gatherDataSets, -)
#   used(log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599, bdp:427a-3cn5, -, [prov:type="ont:Retrieval"])
#   entity(bdp:jbcd-dknd, [ont:Extension="json", prov:label="Mayors 24 Hour Hotline", prov:type="ont:DataResource"])
#   activity(log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c, -, -, [prov:label="Get Mayors 24 Hour Hotline"])
#   wasAssociatedWith(log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c, alg:andradej_chojoe#gatherDataSets, -)
#   used(log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c, bdp:jbcd-dknd, -, [prov:type="ont:Retrieval"])
#   entity(dat:andradej_chojoe#bigbelly, [prov:label="Big Belly Reports 2014", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:andradej_chojoe#bigbelly, alg:andradej_chojoe#gatherDataSets)
#   wasGeneratedBy(dat:andradej_chojoe#bigbelly, log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e, -)
#   wasDerivedFrom(dat:andradej_chojoe#bigbelly, bdp:nybq-xu5r, log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e, log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e, log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e)
#   entity(dat:andradej_chojoe#trashSch, [prov:label="Trash Schedules by Address", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:andradej_chojoe#trashSch, alg:andradej_chojoe#gatherDataSets)
#   wasGeneratedBy(dat:andradej_chojoe#trashSch, log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d, -)
#   wasDerivedFrom(dat:andradej_chojoe#trashSch, bdp:je5q-tbjf, log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d, log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d, log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d)
#   entity(dat:andradej_chojoe#codeEnf, [prov:label="Code Enforcement - Building and Property Violations", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:andradej_chojoe#codeEnf, alg:andradej_chojoe#gatherDataSets)
#   wasGeneratedBy(dat:andradej_chojoe#codeEnf, log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3, -)
#   wasDerivedFrom(dat:andradej_chojoe#codeEnf, bdp:w39n-pvs8, log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3, log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3, log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3)
#   entity(dat:andradej_chojoe#foodEst, [prov:label="Food Establishment Inspections", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:andradej_chojoe#foodEst, alg:andradej_chojoe#gatherDataSets)
#   wasGeneratedBy(dat:andradej_chojoe#foodEst, log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599, -)
#   wasDerivedFrom(dat:andradej_chojoe#foodEst, bdp:427a-3cn5, log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599, log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599, log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599)
#   entity(dat:andradej_chojoe#hotline, [prov:label="Mayors 24 Hour Hotline", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:andradej_chojoe#hotline, alg:andradej_chojoe#gatherDataSets)
#   wasGeneratedBy(dat:andradej_chojoe#hotline, log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c, -)
#   wasDerivedFrom(dat:andradej_chojoe#hotline, bdp:jbcd-dknd, log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c, log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c, log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c)
# endDocument
# {
#     "entity": {
#         "bdp:jbcd-dknd": {
#             "ont:Extension": "json",
#             "prov:type": "ont:DataResource",
#             "prov:label": "Mayors 24 Hour Hotline"
#         },
#         "dat:andradej_chojoe#bigbelly": {
#             "prov:type": "ont:DataSet",
#             "prov:label": "Big Belly Reports 2014"
#         },
#         "dat:andradej_chojoe#codeEnf": {
#             "prov:type": "ont:DataSet",
#             "prov:label": "Code Enforcement - Building and Property Violations"
#         },
#         "bdp:je5q-tbjf": {
#             "ont:Extension": "json",
#             "prov:type": "ont:DataResource",
#             "prov:label": "Trash Schedules by Address"
#         },
#         "dat:andradej_chojoe#hotline": {
#             "prov:type": "ont:DataSet",
#             "prov:label": "Mayors 24 Hour Hotline"
#         },
#         "dat:andradej_chojoe#foodEst": {
#             "prov:type": "ont:DataSet",
#             "prov:label": "Food Establishment Inspections"
#         },
#         "dat:andradej_chojoe#trashSch": {
#             "prov:type": "ont:DataSet",
#             "prov:label": "Trash Schedules by Address"
#         },
#         "bdp:nybq-xu5r": {
#             "ont:Extension": "json",
#             "prov:type": "ont:DataResource",
#             "prov:label": "Big Belly Reports 2014"
#         },
#         "bdp:427a-3cn5": {
#             "ont:Extension": "json",
#             "prov:type": "ont:DataResource",
#             "prov:label": "Food Establishment Inspections"
#         },
#         "bdp:w39n-pvs8": {
#             "ont:Extension": "json",
#             "prov:type": "ont:DataResource",
#             "prov:label": "Code Enforcement - Building and Property Violations"
#         }
#     },
#     "wasGeneratedBy": {
#         "_:id15": {
#             "prov:entity": "dat:andradej_chojoe#trashSch",
#             "prov:activity": "log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d"
#         },
#         "_:id21": {
#             "prov:entity": "dat:andradej_chojoe#foodEst",
#             "prov:activity": "log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599"
#         },
#         "_:id12": {
#             "prov:entity": "dat:andradej_chojoe#bigbelly",
#             "prov:activity": "log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e"
#         },
#         "_:id18": {
#             "prov:entity": "dat:andradej_chojoe#codeEnf",
#             "prov:activity": "log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3"
#         },
#         "_:id24": {
#             "prov:entity": "dat:andradej_chojoe#hotline",
#             "prov:activity": "log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c"
#         }
#     },
#     "agent": {
#         "alg:andradej_chojoe#gatherDataSets": {
#             "ont:Extension": "py",
#             "prov:type": {
#                 "$": "prov:SoftwareAgent",
#                 "type": "prov:QUALIFIED_NAME"
#             }
#         }
#     },
#     "used": {
#         "_:id8": {
#             "prov:entity": "bdp:427a-3cn5",
#             "prov:type": "ont:Retrieval",
#             "prov:activity": "log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599"
#         },
#         "_:id2": {
#             "prov:entity": "bdp:nybq-xu5r",
#             "prov:type": "ont:Retrieval",
#             "prov:activity": "log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e"
#         },
#         "_:id4": {
#             "prov:entity": "bdp:je5q-tbjf",
#             "prov:type": "ont:Retrieval",
#             "prov:activity": "log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d"
#         },
#         "_:id10": {
#             "prov:entity": "bdp:jbcd-dknd",
#             "prov:type": "ont:Retrieval",
#             "prov:activity": "log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c"
#         },
#         "_:id6": {
#             "prov:entity": "bdp:w39n-pvs8",
#             "prov:type": "ont:Retrieval",
#             "prov:activity": "log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3"
#         }
#     },
#     "wasAttributedTo": {
#         "_:id11": {
#             "prov:entity": "dat:andradej_chojoe#bigbelly",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id14": {
#             "prov:entity": "dat:andradej_chojoe#trashSch",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id20": {
#             "prov:entity": "dat:andradej_chojoe#foodEst",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id17": {
#             "prov:entity": "dat:andradej_chojoe#codeEnf",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id23": {
#             "prov:entity": "dat:andradej_chojoe#hotline",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         }
#     },
#     "activity": {
#         "log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3": {
#             "prov:label": "Get Code Enforcement - Building and Property Violations"
#         },
#         "log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d": {
#             "prov:label": "Get Trash Schedules by Address "
#         },
#         "log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599": {
#             "prov:label": "Get Food Establishment Inspections"
#         },
#         "log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c": {
#             "prov:label": "Get Mayors 24 Hour Hotline"
#         },
#         "log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e": {
#             "prov:label": "Get Big Belly Reports 2014"
#         }
#     },
#     "wasDerivedFrom": {
#         "_:id16": {
#             "prov:usage": "log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d",
#             "prov:generation": "log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d",
#             "prov:activity": "log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d",
#             "prov:usedEntity": "bdp:je5q-tbjf",
#             "prov:generatedEntity": "dat:andradej_chojoe#trashSch"
#         },
#         "_:id19": {
#             "prov:usage": "log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3",
#             "prov:generation": "log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3",
#             "prov:activity": "log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3",
#             "prov:usedEntity": "bdp:w39n-pvs8",
#             "prov:generatedEntity": "dat:andradej_chojoe#codeEnf"
#         },
#         "_:id25": {
#             "prov:usage": "log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c",
#             "prov:generation": "log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c",
#             "prov:activity": "log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c",
#             "prov:usedEntity": "bdp:jbcd-dknd",
#             "prov:generatedEntity": "dat:andradej_chojoe#hotline"
#         },
#         "_:id22": {
#             "prov:usage": "log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599",
#             "prov:generation": "log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599",
#             "prov:activity": "log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599",
#             "prov:usedEntity": "bdp:427a-3cn5",
#             "prov:generatedEntity": "dat:andradej_chojoe#foodEst"
#         },
#         "_:id13": {
#             "prov:usage": "log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e",
#             "prov:generation": "log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e",
#             "prov:activity": "log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e",
#             "prov:usedEntity": "bdp:nybq-xu5r",
#             "prov:generatedEntity": "dat:andradej_chojoe#bigbelly"
#         }
#     },
#     "prefix": {
#         "alg": "http://datamechanics.io/algorithm/andradej_chojoe",
#         "dat": "http://datamechanics.io/data/andradej_chojoe",
#         "log": "http://datamechanics.io/log/",
#         "bdp": "https://data.cityofboston.gov/resource/",
#         "ont": "http://datamechanics.io/ontology#"
#     },
#     "wasAssociatedWith": {
#         "_:id1": {
#             "prov:activity": "log:uuid6b251b83-de68-4ea0-af34-c73c0ca0568e",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id5": {
#             "prov:activity": "log:uuidafd3d15c-53de-4feb-bbc6-80a08933d8c3",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id9": {
#             "prov:activity": "log:uuid11e9b811-0be1-4585-8c80-fe62421f8c5c",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id3": {
#             "prov:activity": "log:uuid9e12c4c7-94e6-484b-9cf7-e15ebef8173d",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         },
#         "_:id7": {
#             "prov:activity": "log:uuid17cfe67d-d394-43fc-b4fe-f1c01eaeb599",
#             "prov:agent": "alg:andradej_chojoe#gatherDataSets"
#         }
#     }
# }
