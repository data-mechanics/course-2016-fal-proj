# %%
import pandas as pd

# %%
df = pd.read_json("https://data.cityofboston.gov/resource/4tie-bhxw.json")

# %%
df.head(10)
# Out:
#    :@computed_region_aywg_kpfh         area  \
# 0                        10060   Dorchester
# 1                          NaN    South End
# 2                        16881   Somerville
# 3                        10054       Boston
# 4                        10055      Roxbury
# 5                        10065  Charlestown
# 6                        10057      Roxbury
# 7                        16887   Somerville
# 8                        16547    Cambridge
# 9                        10059   Dorchester
#
#                                                hours            location  \
# 0                                                NaN     10 Melville Ave
# 1                            Saturdays 10:30 - 12:00  1860 Washington St
# 2                          Alt. Wed. 12:30 – 1:30 PM    74 Washington St
# 3                                                NaN       67 Newbury St
# 4                                                NaN    818 Harrison Ave
# ...

# %%
df.shape
# Out:
# (83, 12)

# %%
df.dtypes
# Out:
# :@computed_region_aywg_kpfh    float64
# area                            object
# hours                           object
# location                        object
# location_1                      object
# location_1_city                 object
# location_1_location             object
# location_1_state                object
# name                            object
# site_number                     object
# source                          object
# zip_code                         int64
# dtype: object

# %%
df.groupby('zip_code').count()
# Out:
#           :@computed_region_aywg_kpfh  area  hours  location  location_1  \
# zip_code
# 2108                                1     1      0         1           1
# 2109                                1     1      0         1           1
# 2110                                1     0      0         1           1
# 2111                                1     1      0         1           1
# 2112                                1     1      0         1           1
# 2113                                1     1      0         1           1
# 2116                                4     4      1         4           4
# 2118                               12    12      1        12          12
# 2119                                6     6      4         6           6
# 2120                                2     2      1         2           2
# 2122                                5     5      5         5           5
# 2124                                7     7      5         7           7
# ...
